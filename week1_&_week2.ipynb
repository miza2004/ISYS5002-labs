# %% [markdown]
# <a href="https://colab.research.google.com/github/miza2004/ISYS5002-labs/blob/main/week1_%26_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
from datetime import date
print("Today's date is " + str(date.today()))
# Out:
# Today's date is 2026-02-26

# %%
my_name = input("What is your name? ")
print(my_name)
# Out:
# What is your name? Miza
# Miza

# %%
import math
A = math.sqrt(2)
print(A)
print(A*A)
# Out:
# 1.4142135623730951
# 2.0000000000000004

# %%
A = "1aa3fa875f3d8e55f662872cfb16ed43"
B = "1aa3fa875f3d8e55f667282cfb16ed43"
C = "1aa3fa875f3d8e55f662872cfb16ed43"
print(A == B)
print(B == C)
print(A == C)
# Out:
# False
# False
# True

# %%
A=2
print(A==2)
print(A==5)
A="pizza"
print(A==2)
print(A=="pizza")
# Out:
# True
# False
# False
# True

# %%
from decimal import Decimal
point_one = Decimal('0.1')
point_two = Decimal('0.2')
print(point_one + point_two)
# Out:
# 0.3
