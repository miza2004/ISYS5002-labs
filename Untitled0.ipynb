# %% [markdown]
# <a href="https://colab.research.google.com/github/miza2004/ISYS5002-labs/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = "1aa3fa875f3d8e55f662872cfb16ed43"
B = "1aa3fa875f3d8e55f667282cfb16ed43"
C = "1aa3fa875f3d8e55f662872cfb16ed43"
print(A == B)
print(B == C)
print(A == C)
# Out:
# False
# False
# True

# %%
X = False
print(X)
X = True
print(X)
# Out:
# False
# True

# %%
3 == 4
# Out:
# False

# %%
1 == 3 or 1 == 1
# Out:
# True

# %%
1 == 3 and 1 == 1
# Out:
# False

# %%
1 < 3
# Out:
# True

# %%
1 > 3
# Out:
# False

# %%
3 < 3
# Out:
# False

# %%
3 <= 3
# Out:
# True

# %%
3 == 3
# Out:
# True

# %%
temperature = 18
if temperature < 20:
  print("It's chilly!")
else:
  print("It's warm!")
# Out:
# It's chilly!

# %%
if True:
  print("True")
else:
  print("False")
# Out:
# True

# %%
temperature = 22
is_raining = False
if temperature > 20 and not is_raining:
  print("Great day for a picnic!")
# Out:
# Great day for a picnic!

# %%
temperature = 22
if temperature < 0:
  print("Are you frozen?")
elif temperature >= 0 and temperature < 15:
  print("You're not frozen but you could be warmer")
elif temperature >= 15 and temperature < 25:
  print("I hope I hope you're rather comfortable now")
elif temperature >= 25 and temperature < 35:
  print("Rather warm today, no?")
else:
  print("Too hot...")
# Out:
# I hope I hope you're rather comfortable now

# %%
temperature = 22
if temperature < 0:
  print("Are you frozen?")
elif temperature < 15:
  print("You're not frozen but you could be warmer")
elif temperature < 25:
  print("I hope I hope you're rather comfortable now")
elif temperature < 35:
  print("Rather warm today, no?")
else:
  print("Too hot...")
# Out:
# I hope I hope you're rather comfortable now

# %%
temperature = int(input("Enter the current temperature: "))
if temperature < 15:
  print("It's quite cold today.")
elif temperature < 25:
  print("It's a pleasant day.")
else:
  print("It's hot today!")
# Out:
# Enter the current temperature: 12
# It's quite cold today.

# %%
temperature = int(input("Enter the current temperature: "))
if temperature < 15:
  print("It's quite cold today.")
elif temperature < 25:
  print("It's a pleasant day.")
else:
  print("It's hot today!")
# Out:
# Enter the current temperature: 26
# It's hot today!

# %%
temperature = int(input("Enter the current temperature: "))
if temperature < 15:
  print("It's quite cold today.")
elif temperature < 25:
  print("It's a pleasant day.")
else:
  print("It's hot today!")
# Out:
# Enter the current temperature: 15
# It's a pleasant day.
